# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
#to change the style of the panda dataframes. make it clearer to view content and headers
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df = pd.read_csv('test1.csv', index_col=None)
pd.set_option('display.max_columns', 43) #to view all the columns
#pd.reset_option('display.max_columns') #if we want to reset the columns
df = df.sort('step', ascending = True)
df.head(50)

# %%
#check file dimensions
print(len(df), df.shape)
# Out:
# 586742 (586742, 43)

# %%
test2.head(2)
# Out:
#    GROUP    DISPLAY    SUBJECT           Time      TICK  Steer  Brake  Accel  \
# 0      1  WRISTBAND  HYEONGMIN  06H33M37.1182  19287900    133      0   3381
# 1      1  WRISTBAND  HYEONGMIN  06H33M37.1192  19287901    133      0   3381
#
#    Button 5  Button 6  Combination 6button Input / Output  \
# 0         0         0                    0            NaN
# 1         0         0                    0            NaN
#
#    4level signal pattern  5level signal pattern  Warning_Sig  Drowsiness  \
# 0                     -1                     -1          4.0        0.75
# 1                     -1                     -1          NaN         NaN
#
#    Carelessness  PERCLOS  EyeLidOpening  Carelessness_DSM  Head_Vertical  \
# 0          0.24      2.0            0.0               0.0            0.0
# 1           NaN      NaN            NaN               NaN            NaN
#
#    Head_Horizontal  Eye_Closed_Time  Head_direction_Time  Fatigability  \
# ...

# %%
test2 = df
test2.set_index(['GROUP', 'DISPLAY', 'SUBJECT'])
# Out:
#                                     Time      TICK  Steer  Brake  Accel  \
# GROUP DISPLAY   SUBJECT
# 1     WRISTBAND HYEONGMIN  06H33M37.1182  19287900    133      0   3381
#                 HYEONGMIN  06H33M37.1192  19287901    133      0   3381
#                 HYEONGMIN  06H33M37.1202  19287902    133      0   3381
#                 HYEONGMIN  06H33M37.1212  19287903    133      0   3381
#                 HYEONGMIN  06H33M37.1222  19287904    133      0   3641
#                 HYEONGMIN  06H33M37.1232  19287905    133      0   3641
#                 HYEONGMIN  06H33M37.1242  19287906    133      0   3641
#                 HYEONGMIN  06H33M37.1252  19287907    133      0   2861
#                 HYEONGMIN  06H33M37.1262  19287908    133      0   2861
#                 HYEONGMIN  06H33M37.1272  19287909    133      0   2861
#                 HYEONGMIN  06H33M37.1282  19287910    133      0   3381
#                 HYEONGMIN  06H33M37.1292  19287911    133      0   3381
# ...

# %%
empty1 = pd.DataFrame(np.nan, index=[0], columns=['A', 'B'])
empty1
# Out:
#     A   B
# 0 NaN NaN
